# %% [markdown]
# # LoadFile.py Step by step

# %% [markdown]
# 1 - We import the pylab tools

# %%
from pylab import *

# %% [markdown]
# 2 - We load the txt file containing the EMG signal

# %%
data = loadtxt("SampleEMG.txt")

# %% [markdown]
# 3 - We plot the data, located at column 5

# %%
plot(data[:,5])
show()
